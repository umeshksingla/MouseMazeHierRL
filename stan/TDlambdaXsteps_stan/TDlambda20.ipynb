# %% [markdown]
# ## TD Lambda X Steps

# %%
import pickle

# %%
import sys
module_path = 'src' 
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from parameters import *

# %%
from model_plot_utils import plot_trajectory

# %%
from TDLambdaXSteps_model import TDLambdaXStepsRewardReceived

# %%
model = TDLambdaXStepsRewardReceived()

# %%
nodemap = model.get_SAnodemap()

# %%
trajectory_data = model.extract_trajectory_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-8cddf3a1c6a1> in <module>
# ----> 1 trajectory_data = model.extract_trajectory_data()
#
# ~/mouse-maze/MouseMaze/src/TDLambdaXSteps_model.py in extract_trajectory_data(self, save_dir)
#      26         trajectory_data = []
#      27         for mouseId, nickname in enumerate(RewNames):
# ---> 28             trajectory_data.append(self.__get_trajectory_data_by_nickname__(orig_data_dir, nickname))
#      29         if save_dir:
#      30             with open(os.path.join(save_dir, f'{self.file_suffix}.p'), 'wb') as f:
#
# ~/mouse-maze/MouseMaze/src/TDLambdaXSteps_model.py in __get_trajectory_data_by_nickname__(self, nickname)
#      34     def __get_trajectory_data_by_nickname__(self, orig_data_dir, nickname):
#      35         tf = LoadTrajFromPath(os.path.join(orig_data_dir, nickname + '-tf'))
# ---> 36         trajectory_data = []
#      37
#      38         for boutId, reward_frames in enumerate(tf.re):
#
# ~/mouse-maze/MouseMaze/src/MM_Traj_Utils.py in LoadTrajFromPath(path)
#      51     Puts the results in a Traj structure.
#      52     '''
# ---> 53     with open(path, 'rb') as f:
#      54         return pickle.load(f)
#      55
#
# FileNotFoundError: [Errno 2] No such file or directory: '../outdata/B1-tf'

# %%
trajectory_data[0][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-81ca818185db> in <module>
# ----> 1 trajectory_data[0][0]
#
# NameError: name 'trajectory_data' is not defined

# %%
TrajS = model.load_trajectories_from_object(trajectory_data)

# %%
TrajS[0][0]
# Out:
# array([ 62, 125,  62, 126,  62,  30,  61, 124,  61,  30,  14,  30,  14,
#         29,  14,   6,  13,  28,  57, 116, 128])

# %%
TrajA = model.load_TrajA(TrajS, nodemap)

# %%
TrajA[0][0]
# Out:
# array([2, 1, 3, 1, 1, 2, 3, 1, 1, 1, 3, 1, 2, 1, 1, 2, 3, 2, 3, 0, 0])

# %%
plot_trajectory({0: TrajS[0][0][:-1]}, 'all')

# %%
# IGNORE!!!

# Plotting results from running TD(0) model above

# Plotting state values
fig, ax = plt.subplots(figsize=(30,800))
axhandle = ax.imshow(np.transpose(np.reshape(avg_V,(S+1,1))),cmap='YlGnBu')
ax.invert_yaxis()
ax.set_ylabel('V (s)')
ax.set_xticks(np.arange(0,127,5))
ax.set_xticklabels([str(val) for val in np.arange(0,127,5)])
ax.set_xlabel('Nodes')
ax.set_title('Average state values for TD(0) with alpha: %.2f, beta: %.2f and gamma: %.2f' % (alpha,beta,gamma))
fig.colorbar(axhandle,fraction=0.005)

print('Max state value ', np.max(avg_V))
print('Min state value', np.min(avg_V))

# Set trajectories for plotting
print('Total reward: ', total_reward)
print('alpha: ', alpha, ' beta: ', beta, ' gamma: ', gamma)
plot_trajectory(state_hist_all, 'all')
